# %%
#Integer
a = 10
print(a, type(a))
# Out:
# 10 <class 'int'>

# %%
#Float
b = 3.14
print(b, type(b))
# Out:
# 3.14 <class 'float'>

# %%
#String
c = "Hello"
print(c, type(c))
# Out:
# Hello <class 'str'>

# %%
#Boolean
d = True
print(d, type(d))
# Out:
# True <class 'bool'>

# %%
# List
e = [1, 2, 3]
print(e, type(e))
# Out:
# [1, 2, 3] <class 'list'>

# %%
#Tuple
f = (10, 20)
print(f, type(f))
# Out:
# (10, 20) <class 'tuple'>

# %%
# Set
g = {1, 2, 3}
print(g, type(g))
# Out:
# {1, 2, 3} <class 'set'>

# %%
#Dictionary
h = {"name": "Sruthi", "age": 21}
print(h, type(h))
# Out:
# {'name': 'Sruthi', 'age': 21} <class 'dict'>

# %%
#Basic Python
x = 10
y = 25.5
name = "Sruthi"
is_student = True

# %%
#Multiple
a, b, c = 1, 2, 3
print(a, b, c)
# Out:
# 1 2 3

# %%
#Same Value to Multiple
x = y = z = 100
print(x, y, z)
# Out:
# 100 100 100

# %%
#Different Datatype
age = 21
height = 5.4
grade = 'A'
college = "ABC"

# %%
#Input
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Name:", name)
print("Age:", age)
# Out:
# Enter your name: sruthi
# Enter your age: 21
# Name: sruthi
# Age: 21
